# %%
import os
from pathlib import Path
#sudo apt install rename

# %%
cd 2022-03-17
# Out:
# C:\Users\Owner\Desktop\windtunnel\2022-03-17

# %%
file_list = os.listdir(Path.cwd())

Date = '220317'

index=0
for file in file_list:
    name_parts = file.split('-') # = [hh-mm-ss.******.jpg']
    print(name_parts)
    pre = 'tl_0000_' 
    index += 1
    count = '%04d' % index
    sep = '_'
    hh = name_parts[0][0:2] 
    mm = name_parts[1][0:2] 
    ss = name_parts[2][0:2]
    ext = '.jpg'
    new_file =  ''.join([pre,count,sep,Date,sep,hh,mm,ss,ext])
    
    print(new_file)
    #try:
    #    os.rename(file, new_file)
# Out:
# ['13', '47', '54.484326.jpg']
# tl_0000_0001_220317_134754.jpg
# ['13', '47', '55.219993.jpg']
# tl_0000_0002_220317_134755.jpg
# ['13', '47', '55.719357.jpg']
# tl_0000_0003_220317_134755.jpg
# ['13', '47', '56.213795.jpg']
# tl_0000_0004_220317_134756.jpg
# ['13', '47', '56.704917.jpg']
# tl_0000_0005_220317_134756.jpg
# ['13', '47', '57.217334.jpg']
# tl_0000_0006_220317_134757.jpg
# ['13', '47', '57.715110.jpg']
# tl_0000_0007_220317_134757.jpg
# ['13', '47', '58.216136.jpg']
# tl_0000_0008_220317_134758.jpg
# ['13', '47', '58.714319.jpg']
# tl_0000_0009_220317_134758.jpg
# ['13', '47', '59.222934.jpg']
# tl_0000_0010_220317_134759.jpg
# ['13', '47', '59.719374.jpg']
# tl_0000_0011_220317_134759.jpg
# ['13', '48', '00.214619.jpg']
# tl_0000_0012_220317_134800.jpg
# ['13', '48', '00.714537.jpg']
# tl_0000_0013_220317_134800.jpg
# ['13', '48', '01.218041.jpg']
# tl_0000_0014_220317_134801.jpg
# ['13', '48', '01.711402.jpg']
# tl_0000_0015_220317_134801.jpg
# ...
